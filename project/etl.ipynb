# %% [markdown]
# # Impact of Climate change on various species of trees in Frankfurt

# %% [markdown]
# Coorelation of Planation year temperature with the crown diameter, trunk height etc of various species of trees?
# How it varies across different species of plants?

# %% [markdown]
# ## Extraction from 2 CSV files

# %%
#import required dependencies here:
import pandas as pd
#from config import db_password

# %%
#read csv 1
df1 = pd.read_csv("https://offenedaten.frankfurt.de/dataset/73c5a6b3-c033-4dad-bb7d-8783427dd233/resource/257690bb-f40a-4e3a-93da-1310214f392f/download/baumauswahl.csv",sep = ';')
# Out:
#    OBJECTID BAUMNUMMER    HOCHWERT  RECHTSWERT   GATTUNG  \
# 0         1          1   5549510,9  473366,239  Platanus
# 1         2          2  5549517,24  473363,459  Platanus
# 2         3          3  5549524,39  473360,149  Platanus
# 3         4          5  5549537,75  473354,479  Platanus
# 4         5          6  5549544,09  473351,429  Platanus
#
#                                     GA_LANG KR_DURCHM  ST_UMFANG  \
# 0  Platanus acerifolia, Gewöhnliche Platane         8        141
# 1  Platanus acerifolia, Gewöhnliche Platane         8        141
# 2  Platanus acerifolia, Gewöhnliche Platane         8        138
# 3  Platanus acerifolia, Gewöhnliche Platane         8        141
# 4  Platanus acerifolia, Gewöhnliche Platane         8        132
#
#             STRASSE  BAUMHOEHE  ST_DURCHM  PFLANZJAHR
# 0  Ackermannstrasse          7         45        1920
# 1  Ackermannstrasse          7         45        1920
# 2  Ackermannstrasse          7         44        1920
# 3  Ackermannstrasse          7         45        1920
# 4  Ackermannstrasse          7         42        1920

# %%
url='https://github.com/omerjadoon/TemperatureData/raw/main/temperature.csv.zip'
df2 = pd.read_csv(url)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %% [markdown]
# # Transform

# %%
frankfurt_df = df2[df2['City'] == 'Frankfurt']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 2390296  1743-11-01               5.354                          1.636
# 2390297  1743-12-01                 NaN                            NaN
# 2390298  1744-01-01                 NaN                            NaN
# 2390299  1744-02-01                 NaN                            NaN
# 2390300  1744-03-01                 NaN                            NaN
#
#               City  Country Latitude Longitude
# 2390296  Frankfurt  Germany   50.63N     8.87E
# 2390297  Frankfurt  Germany   50.63N     8.87E
# 2390298  Frankfurt  Germany   50.63N     8.87E
# 2390299  Frankfurt  Germany   50.63N     8.87E
# 2390300  Frankfurt  Germany   50.63N     8.87E

# %%
#drop last 3 columns
frankfurt_df.drop(frankfurt_df.columns[[2,3,4,5,6]], axis=1, inplace=True)
# Out:
# C:\Users\omerk\AppData\Local\Temp\ipykernel_6760\1385952423.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frankfurt_df.drop(frankfurt_df.columns[[2,3,4,5,6]], axis=1, inplace=True)
#                  dt  AverageTemperature
# 2390296  1743-11-01               5.354
# 2390297  1743-12-01                 NaN
# 2390298  1744-01-01                 NaN
# 2390299  1744-02-01                 NaN
# 2390300  1744-03-01                 NaN

# %%
age_nan_count = frankfurt_df['AverageTemperature'].isna().sum()

print(f"Number of NaN values in 'Age' column: {age_nan_count}")
# Out:
# Number of NaN values in 'Age' column: 73

# %%
df2_cleaned = frankfurt_df.dropna(subset=['AverageTemperature'])
# Out:
#                  dt  AverageTemperature
# 2390296  1743-11-01               5.354
# 2390301  1744-04-01               8.545
# 2390302  1744-05-01              11.554
# 2390303  1744-06-01              14.384
# 2390304  1744-07-01              16.287
# 2390306  1744-09-01              12.827
# 2390307  1744-10-01               8.420
# 2390308  1744-11-01               4.035
# 2390309  1744-12-01               0.153
# 2390310  1745-01-01              -2.309

# %%
df2_cleaned['dt'] = pd.to_datetime(df2_cleaned['dt'])

# Step 3: Extract the year from the 'dt' column
df2_cleaned['Year'] = df2_cleaned['dt'].dt.year

# Step 4: Group by the year and calculate the average temperature per year
annual_avg_temp_df = df2_cleaned.groupby('Year')['AverageTemperature'].mean().reset_index()

# Display the result
print(annual_avg_temp_df)
# Out:
#      Year  AverageTemperature
# 0    1743            5.354000
# 1    1744            9.525625
# 2    1745            1.430750
# 3    1750            9.059636
# 4    1751            8.980750
# ..    ...                 ...
# 262  2009            9.319750
# 263  2010            8.055667
# 264  2011            9.937750
# 265  2012            9.215667
# 266  2013            9.245625
#
# [267 rows x 2 columns]
# C:\Users\omerk\AppData\Local\Temp\ipykernel_6760\3900274951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned['dt'] = pd.to_datetime(df2_cleaned['dt'])
# C:\Users\omerk\AppData\Local\Temp\ipykernel_6760\3900274951.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_cleaned['Year'] = df2_cleaned['dt'].dt.year

# %%
extended_df = pd.merge(df1, annual_avg_temp_df, left_on='PFLANZJAHR', right_on='Year', how='left')

# Drop the 'dt' column as it's no longer needed
extended_df = extended_df.drop(columns=['Year'])
# Out:
#         OBJECTID BAUMNUMMER     HOCHWERT   RECHTSWERT      GATTUNG  \
# 0              1          1    5549510,9   473366,239     Platanus
# 1              2          2   5549517,24   473363,459     Platanus
# 2              3          3   5549524,39   473360,149     Platanus
# 3              4          5   5549537,75   473354,479     Platanus
# 4              5          6   5549544,09   473351,429     Platanus
# ...          ...        ...          ...          ...          ...
# 161814    168473       30/A  5551546,134  466838,7476  Amelanchier
# 161815    168474       30/B  5551544,734  466839,3165  Amelanchier
# 161816    168475       39/A  5551506,662  466877,5127       Prunus
# 161817    168476       39/B  5551506,488  466875,2865       Prunus
# 161818    168477        110   5554483,75    480622,75       Sorbus
#
#                                           GA_LANG KR_DURCHM  ST_UMFANG  \
# 0        Platanus acerifolia, Gewöhnliche Platane         8        141
# 1        Platanus acerifolia, Gewöhnliche Platane         8        141
# 2        Platanus acerifolia, Gewöhnliche Platane         8        138
# 3        Platanus acerifolia, Gewöhnliche Platane         8        141
# 4        Platanus acerifolia, Gewöhnliche Platane         8        132
# ...                                           ...       ...        ...
# 161814  Amelanchier lamarckii, Kupfer-Felsenbirne       2,5         38
# 161815  Amelanchier lamarckii, Kupfer-Felsenbirne         3         66
# 161816     Prunus serotina, Späte Trauben-Kirsche         5         69
# 161817     Prunus serotina, Späte Trauben-Kirsche         5         79
# 161818               Sorbus domestica, Speierling         3         31
#
#                       STRASSE  BAUMHOEHE  ST_DURCHM  PFLANZJAHR  \
# 0            Ackermannstrasse          7         45        1920
# 1            Ackermannstrasse          7         45        1920
# 2            Ackermannstrasse          7         44        1920
# 3            Ackermannstrasse          7         45        1920
# 4            Ackermannstrasse          7         42        1920
# ...                       ...        ...        ...         ...
# 161814  Engelsruhe Spielplatz          3         12        2000
# 161815  Engelsruhe Spielplatz          5         21        2000
# 161816  Engelsruhe Spielplatz          2         22        2000
# 161817  Engelsruhe Spielplatz          2         25        2000
# 161818           Seckbach Süd          7         10        2018
#
#         AverageTemperature
# 0                 8.561250
# 1                 8.561250
# 2                 8.561250
# 3                 8.561250
# 4                 8.561250
# ...                    ...
# 161814            9.962583
# 161815            9.962583
# 161816            9.962583
# 161817            9.962583
# 161818                 NaN
#
# [161819 rows x 13 columns]

# %%
extended_df = extended_df.rename(columns={
    "OBJECTID": "ObjectID",
    "BAUMNUMMER": "TreeNumber",
    "HOCHWERT": "Latitude",
    "RECHTSWERT": "Longitude",
    "GATTUNG": "Genus",
    "GA_LANG": "ScientificName",
    "KR_DURCHM": "CrownDiameter",
    "ST_UMFANG": "TrunkCircumference",
    "STRASSE": "Street",
    "BAUMHOEHE": "TreeHeight",
    "ST_DURCHM": "TrunkDiameter",
    "PFLANZJAHR": "PlantingYear",
})
# Out:
#         ObjectID TreeNumber     Latitude    Longitude        Genus  \
# 0              1          1    5549510,9   473366,239     Platanus
# 1              2          2   5549517,24   473363,459     Platanus
# 2              3          3   5549524,39   473360,149     Platanus
# 3              4          5   5549537,75   473354,479     Platanus
# 4              5          6   5549544,09   473351,429     Platanus
# ...          ...        ...          ...          ...          ...
# 161814    168473       30/A  5551546,134  466838,7476  Amelanchier
# 161815    168474       30/B  5551544,734  466839,3165  Amelanchier
# 161816    168475       39/A  5551506,662  466877,5127       Prunus
# 161817    168476       39/B  5551506,488  466875,2865       Prunus
# 161818    168477        110   5554483,75    480622,75       Sorbus
#
#                                    ScientificName CrownDiameter  \
# 0        Platanus acerifolia, Gewöhnliche Platane             8
# 1        Platanus acerifolia, Gewöhnliche Platane             8
# 2        Platanus acerifolia, Gewöhnliche Platane             8
# 3        Platanus acerifolia, Gewöhnliche Platane             8
# 4        Platanus acerifolia, Gewöhnliche Platane             8
# ...                                           ...           ...
# 161814  Amelanchier lamarckii, Kupfer-Felsenbirne           2,5
# 161815  Amelanchier lamarckii, Kupfer-Felsenbirne             3
# 161816     Prunus serotina, Späte Trauben-Kirsche             5
# 161817     Prunus serotina, Späte Trauben-Kirsche             5
# 161818               Sorbus domestica, Speierling             3
#
#         TrunkCircumference                 Street  TreeHeight  TrunkDiameter  \
# 0                      141       Ackermannstrasse           7             45
# 1                      141       Ackermannstrasse           7             45
# 2                      138       Ackermannstrasse           7             44
# 3                      141       Ackermannstrasse           7             45
# 4                      132       Ackermannstrasse           7             42
# ...                    ...                    ...         ...            ...
# 161814                  38  Engelsruhe Spielplatz           3             12
# 161815                  66  Engelsruhe Spielplatz           5             21
# 161816                  69  Engelsruhe Spielplatz           2             22
# 161817                  79  Engelsruhe Spielplatz           2             25
# 161818                  31           Seckbach Süd           7             10
#
#         PlantingYear  AverageTemperature
# 0               1920            8.561250
# 1               1920            8.561250
# 2               1920            8.561250
# 3               1920            8.561250
# 4               1920            8.561250
# ...              ...                 ...
# 161814          2000            9.962583
# 161815          2000            9.962583
# 161816          2000            9.962583
# 161817          2000            9.962583
# 161818          2018                 NaN
#
# [161819 rows x 13 columns]

# %%
extended_df.drop(columns=["ObjectID", "TreeNumber", "Latitude", "Longitude", "ScientificName", "Street"], axis=1, inplace=True)
# Out:
#               Genus CrownDiameter  TrunkCircumference  TreeHeight  \
# 0          Platanus             8                 141           7
# 1          Platanus             8                 141           7
# 2          Platanus             8                 138           7
# 3          Platanus             8                 141           7
# 4          Platanus             8                 132           7
# ...             ...           ...                 ...         ...
# 161814  Amelanchier           2,5                  38           3
# 161815  Amelanchier             3                  66           5
# 161816       Prunus             5                  69           2
# 161817       Prunus             5                  79           2
# 161818       Sorbus             3                  31           7
#
#         TrunkDiameter  PlantingYear  AverageTemperature
# 0                  45          1920            8.561250
# 1                  45          1920            8.561250
# 2                  44          1920            8.561250
# 3                  45          1920            8.561250
# 4                  42          1920            8.561250
# ...               ...           ...                 ...
# 161814             12          2000            9.962583
# 161815             21          2000            9.962583
# 161816             22          2000            9.962583
# 161817             25          2000            9.962583
# 161818             10          2018                 NaN
#
# [161819 rows x 7 columns]

# %%
extended_df.dropna()
# Out:
#               Genus CrownDiameter  TrunkCircumference  TreeHeight  \
# 0          Platanus             8                 141           7
# 1          Platanus             8                 141           7
# 2          Platanus             8                 138           7
# 3          Platanus             8                 141           7
# 4          Platanus             8                 132           7
# ...             ...           ...                 ...         ...
# 161813  Amelanchier             4                  85           5
# 161814  Amelanchier           2,5                  38           3
# 161815  Amelanchier             3                  66           5
# 161816       Prunus             5                  69           2
# 161817       Prunus             5                  79           2
#
#         TrunkDiameter  PlantingYear  AverageTemperature
# 0                  45          1920            8.561250
# 1                  45          1920            8.561250
# 2                  44          1920            8.561250
# 3                  45          1920            8.561250
# 4                  42          1920            8.561250
# ...               ...           ...                 ...
# 161813             27          2000            9.962583
# 161814             12          2000            9.962583
# 161815             21          2000            9.962583
# 161816             22          2000            9.962583
# 161817             25          2000            9.962583
#
# [149987 rows x 7 columns]

# %% [markdown]
# # Load

# %%
extended_df.to_csv('../data/data.csv')
